# %%
from pathlib import Path

cwd = Path.cwd()
data_dir = cwd / "datasets" / "DryBeanDataset"
data_path = data_dir / "Dry_Bean_Dataset.xlsx"

# %%
data_path
# Out:
# PosixPath('/home/heidless/projects/heidless-python/Data-Science/dry-bean-0/datasets/DryBeanDataset/Dry_Bean_Dataset.xlsx')

# %%
import pandas as pd

beans = pd.read_excel(data_path)

beans.shape
# Out:
# (13611, 17)

# %%
beans
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
beans.to_csv(data_dir / "dry_bean.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 beans.to_csv(cwd / "data" / "dry_bean.csv", index=False)
#
# File ~/miniconda3/envs/dataSci-2/lib/python3.13/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
